# %%
from sqlalchemy import create_engine
import pandas as pd
import os

# %%
# folder path
res_dir = r'results'
db_user = 'postgres'
db_pwd = 'root'
db_name = 'trips_challenge'
db_host = 'localhost'
db_port = '5433'

# dialect+driver://username:password@host:port/database
in_connection_str = "postgresql+psycopg2://" + db_user + ":" + db_pwd + "@" + db_host + ":" + db_port + "/" + db_name
# conect to DB
connIn = create_engine(in_connection_str)

# %%
population = pd.read_sql("SELECT * FROM population", con=connIn)
population
# Out:
#       code                          population
# 0  A048710  Population 35 years old or younger
# 1  A048709   Population: 36 years old or older

# %%
region = pd.read_sql("SELECT * FROM region", con=connIn)
region
# Out:
#         code              region  \
# 0   PV20          Groningen (PV)
# 1   PV21            Fryslân (PV)
# 2   PV22            Drenthe (PV)
# 3   PV23         Overijssel (PV)
# 4   PV24          Flevoland (PV)
# 5   PV25         Gelderland (PV)
# 6   PV26            Utrecht (PV)
# 7   PV27      Noord-Holland (PV)
# 8   PV28       Zuid-Holland (PV)
# 9   PV29            Zeeland (PV)
# 10  PV30      Noord-Brabant (PV)
# 11  PV31            Limburg (PV)
#
#                                           description
# 0   PV = Province Administrative classification of...
# 1   PV = Province Administrative classification of...
# 2   PV = Province Administrative classification of...
# 3   PV = Province Administrative classification of...
# 4   PV = Province Administrative classification of...
# 5   PV = Province Administrative classification of...
# 6   PV = Province Administrative classification of...
# 7   PV = Province Administrative classification of...
# 8   PV = Province Administrative classification of...
# 9   PV = Province Administrative classification of...
# 10  PV = Province Administrative classification of...
# 11  PV = Province Administrative classification of...

# %%
travel_mode = pd.read_sql("SELECT * FROM travel_mode", con=connIn)
travel_mode
# Out:
#       code                       mode  \
# 0  A048583     Passenger car (driver)
# 1  A048584  Passenger car (passenger)
# 2  A018981                      Train
# 3  A018982             Bus/tram/metro
# 4  A018984                       Bike
# 5  A018985                    Walking
# 6  A018986                      Other
#
#                                          description
# 0  This includes drivers of a passenger car (also...
# 1  Person who rides along in a passenger car (wit...
# 2  Includes: express train, stopping train, sprin...
# 3  Bus: this includes only (scheduled) buses for ...
# 4  Bicycle: this includes: both a non-electric an...
# 5  This includes all travel on foot possibly with...
# 6                                               None

# %%
travel_motives = pd.read_sql("SELECT * FROM travel_motives", con=connIn)
travel_motives
# Out:
#       code                                    motive  \
# 0  2030170  Travel to/from work, (non)-daily commute
# 1  2030190                             Services/care
# 2  2030200         Shopping, groceries, funshopping.
# 3  2030210               Attending education/courses
# 4  2030220        Visits including staying overnight
# 5  2030230                           Leisure, sports
# 6  2030240                           Touring/walking
# 7  2030250                                     Other
# 8  2820740                            Professionally
#
#                                          description
# 0  Trips to and from a permanent or a temporary w...
# 1  Trips to a location where a form of service or...
# 2  Shopping, grocery shopping and fun shopping (f...
# 3  Activities related to attending school and chi...
# 4  It involves visiting and possibly staying over...
# 5  This includes sport-related trips such as (whe...
# 6  This mainly includes, in particular, recreatio...
# 7  These include the non-commercial //bringing an...
# 8  Business, professional. Business trips in the ...

# %%
trips = pd.read_sql("SELECT * FROM trips", con=connIn)
trips=trips.drop(trips.columns[[0]],axis = 1)
#trips.info()
trips.dtypes
# Out:
# TravelMotives                 int64
# Population                   object
# TravelModes                  object
# RegionCharacteristics        object
# Periods                      object
# Trip in a year               object
# Km travelled in a year       object
# Hours travelled in a year    object
# UserId                        int64
# dtype: object

# %%
trips.nunique( )
# Out:
# TravelMotives                   9
# Population                     12
# TravelModes                     8
# RegionCharacteristics          14
# Periods                         5
# Trip in a year                228
# Km travelled in a year       1494
# Hours travelled in a year     832
# UserId                       3235
# dtype: int64

# %%
trips['Periods']=trips['Periods'].str.slice(stop=4)

# %%
urbanization_level = pd.read_sql("SELECT * FROM urbanization_level", con=connIn)
urbanization_level=urbanization_level.drop(urbanization_level.columns[[0]],axis = 1)
urbanization_level
# Out:
#              provinces      level_urbanization                  area
# 0   Noord-Holland (PV)     Extremely urbanised  Noord-Nederland (LD)
# 1         Utrecht (PV)      Strongly urbanised   West-Nederland (LD)
# 2   Noord-Brabant (PV)      Strongly urbanised   Zuid-Nederland (LD)
# 3      Gelderland (PV)  Moderately urbanised\t   Oost-Nederland (LD)
# 4         Limburg (PV)    Moderately urbanised   Zuid-Nederland (LD)
# 5      Overijssel (PV)    Moderately urbanised   Oost-Nederland (LD)
# 6       Flevoland (PV)    Moderately urbanised   West-Nederland (LD)
# 7       Groningen (PV)        Hardly urbanised  Noord-Nederland (LD)
# 8         Drenthe (PV)        Hardly urbanised  Noord-Nederland (LD)
# 9         Fryslân (PV)        Hardly urbanised  Noord-Nederland (LD)
# 10        Zeeland (PV)        Hardly urbanised   Zuid-Nederland (LD)

# %%
region_ul = pd.merge(region, urbanization_level, how="left", left_on='region', right_on='provinces')
region_ul
# Out:
#         code              region  \
# 0   PV20          Groningen (PV)
# 1   PV21            Fryslân (PV)
# 2   PV22            Drenthe (PV)
# 3   PV23         Overijssel (PV)
# 4   PV24          Flevoland (PV)
# 5   PV25         Gelderland (PV)
# 6   PV26            Utrecht (PV)
# 7   PV27      Noord-Holland (PV)
# 8   PV28       Zuid-Holland (PV)
# 9   PV29            Zeeland (PV)
# 10  PV30      Noord-Brabant (PV)
# 11  PV31            Limburg (PV)
#
#                                           description           provinces  \
# 0   PV = Province Administrative classification of...      Groningen (PV)
# 1   PV = Province Administrative classification of...        Fryslân (PV)
# 2   PV = Province Administrative classification of...        Drenthe (PV)
# 3   PV = Province Administrative classification of...     Overijssel (PV)
# 4   PV = Province Administrative classification of...      Flevoland (PV)
# 5   PV = Province Administrative classification of...     Gelderland (PV)
# 6   PV = Province Administrative classification of...        Utrecht (PV)
# 7   PV = Province Administrative classification of...  Noord-Holland (PV)
# 8   PV = Province Administrative classification of...                 NaN
# 9   PV = Province Administrative classification of...        Zeeland (PV)
# 10  PV = Province Administrative classification of...  Noord-Brabant (PV)
# 11  PV = Province Administrative classification of...        Limburg (PV)
#
#         level_urbanization                  area
# 0         Hardly urbanised  Noord-Nederland (LD)
# 1         Hardly urbanised  Noord-Nederland (LD)
# 2         Hardly urbanised  Noord-Nederland (LD)
# 3     Moderately urbanised   Oost-Nederland (LD)
# 4     Moderately urbanised   West-Nederland (LD)
# 5   Moderately urbanised\t   Oost-Nederland (LD)
# 6       Strongly urbanised   West-Nederland (LD)
# 7      Extremely urbanised  Noord-Nederland (LD)
# 8                      NaN                   NaN
# 9         Hardly urbanised   Zuid-Nederland (LD)
# 10      Strongly urbanised   Zuid-Nederland (LD)
# 11    Moderately urbanised   Zuid-Nederland (LD)

# %%
trips_denorm = pd.merge(trips, travel_mode, how="left", left_on='TravelModes', right_on='code')
trips_denorm
# Out:
#       TravelMotives Population TravelModes RegionCharacteristics Periods  \
# 0           2030250    A048710     A048583              PV23        2020
# 1           2030220    A048709     T001093              PV30        2019
# 2           2030170    A048710     A018984              PV31        2022
# 3           2030220    A048709     A018982              PV20        2020
# 4           2030220    A048710     A048584              PV26        2021
# ...             ...        ...         ...                   ...     ...
# 8715        2030200    A048709     T001093              PV30        2020
# 8716        2030190    A048710     A018981              PV28        2022
# 8717        2030230    A048709     A018986              PV23        2020
# 8718        2030250    A048709     A048583              PV31        2021
# 8719        2030240    A048710     A048584              PV29        2020
#
#      Trip in a year Km travelled in a year Hours travelled in a year  UserId  \
# 0                58                    657                      16.5      37
# 1               107                   2208                      50.1    2474
# 2                34                    169                      14.2    1924
# 3                 .                      .                         .     618
# 4                18                    665                      11.9    3153
# ...             ...                    ...                       ...     ...
# 8715            216                    984                      44.1     950
# 8716              .                      .                         .    2292
# 8717              .                      .                         .    1434
# 8718             66                    649                      17.9    1336
# 8719              .                      .                         .    2968
#
#          code                       mode  \
# 0     A048583     Passenger car (driver)
# 1         NaN                        NaN
# 2     A018984                       Bike
# 3     A018982             Bus/tram/metro
# 4     A048584  Passenger car (passenger)
# ...       ...                        ...
# 8715      NaN                        NaN
# 8716  A018981                      Train
# 8717  A018986                      Other
# 8718  A048583     Passenger car (driver)
# 8719  A048584  Passenger car (passenger)
#
#                                             description
# 0     This includes drivers of a passenger car (also...
# 1                                                   NaN
# 2     Bicycle: this includes: both a non-electric an...
# 3     Bus: this includes only (scheduled) buses for ...
# 4     Person who rides along in a passenger car (wit...
# ...                                                 ...
# 8715                                                NaN
# 8716  Includes: express train, stopping train, sprin...
# 8717                                               None
# 8718  This includes drivers of a passenger car (also...
# 8719  Person who rides along in a passenger car (wit...
#
# [8720 rows x 12 columns]

# %%
trips_denorm=pd.merge(trips_denorm, travel_motives, how="left", left_on='TravelMotives', right_on='code', suffixes=('', '_travel_motives'))
trips_denorm
# Out:
#       TravelMotives Population TravelModes RegionCharacteristics Periods  \
# 0           2030250    A048710     A048583              PV23        2020
# 1           2030220    A048709     T001093              PV30        2019
# 2           2030170    A048710     A018984              PV31        2022
# 3           2030220    A048709     A018982              PV20        2020
# 4           2030220    A048710     A048584              PV26        2021
# ...             ...        ...         ...                   ...     ...
# 8715        2030200    A048709     T001093              PV30        2020
# 8716        2030190    A048710     A018981              PV28        2022
# 8717        2030230    A048709     A018986              PV23        2020
# 8718        2030250    A048709     A048583              PV31        2021
# 8719        2030240    A048710     A048584              PV29        2020
#
#      Trip in a year Km travelled in a year Hours travelled in a year  UserId  \
# 0                58                    657                      16.5      37
# 1               107                   2208                      50.1    2474
# 2                34                    169                      14.2    1924
# 3                 .                      .                         .     618
# 4                18                    665                      11.9    3153
# ...             ...                    ...                       ...     ...
# 8715            216                    984                      44.1     950
# 8716              .                      .                         .    2292
# 8717              .                      .                         .    1434
# 8718             66                    649                      17.9    1336
# 8719              .                      .                         .    2968
#
#          code                       mode  \
# 0     A048583     Passenger car (driver)
# 1         NaN                        NaN
# 2     A018984                       Bike
# 3     A018982             Bus/tram/metro
# 4     A048584  Passenger car (passenger)
# ...       ...                        ...
# 8715      NaN                        NaN
# 8716  A018981                      Train
# 8717  A018986                      Other
# 8718  A048583     Passenger car (driver)
# 8719  A048584  Passenger car (passenger)
#
#                                             description  code_travel_motives  \
# 0     This includes drivers of a passenger car (also...              2030250
# 1                                                   NaN              2030220
# 2     Bicycle: this includes: both a non-electric an...              2030170
# 3     Bus: this includes only (scheduled) buses for ...              2030220
# 4     Person who rides along in a passenger car (wit...              2030220
# ...                                                 ...                  ...
# 8715                                                NaN              2030200
# 8716  Includes: express train, stopping train, sprin...              2030190
# 8717                                               None              2030230
# 8718  This includes drivers of a passenger car (also...              2030250
# 8719  Person who rides along in a passenger car (wit...              2030240
#
#                                         motive  \
# 0                                        Other
# 1           Visits including staying overnight
# 2     Travel to/from work, (non)-daily commute
# 3           Visits including staying overnight
# 4           Visits including staying overnight
# ...                                        ...
# 8715         Shopping, groceries, funshopping.
# 8716                             Services/care
# 8717                           Leisure, sports
# 8718                                     Other
# 8719                           Touring/walking
#
#                              description_travel_motives
# 0     These include the non-commercial //bringing an...
# 1     It involves visiting and possibly staying over...
# 2     Trips to and from a permanent or a temporary w...
# 3     It involves visiting and possibly staying over...
# 4     It involves visiting and possibly staying over...
# ...                                                 ...
# 8715  Shopping, grocery shopping and fun shopping (f...
# 8716  Trips to a location where a form of service or...
# 8717  This includes sport-related trips such as (whe...
# 8718  These include the non-commercial //bringing an...
# 8719  This mainly includes, in particular, recreatio...
#
# [8720 rows x 15 columns]

# %%
trips_denorm=pd.merge(trips_denorm, region_ul, how="left", left_on='RegionCharacteristics', right_on='code', suffixes=('', '_region'))
trips_denorm
# Out:
#       TravelMotives Population TravelModes RegionCharacteristics Periods  \
# 0           2030250    A048710     A048583              PV23        2020
# 1           2030220    A048709     T001093              PV30        2019
# 2           2030170    A048710     A018984              PV31        2022
# 3           2030220    A048709     A018982              PV20        2020
# 4           2030220    A048710     A048584              PV26        2021
# ...             ...        ...         ...                   ...     ...
# 8715        2030200    A048709     T001093              PV30        2020
# 8716        2030190    A048710     A018981              PV28        2022
# 8717        2030230    A048709     A018986              PV23        2020
# 8718        2030250    A048709     A048583              PV31        2021
# 8719        2030240    A048710     A048584              PV29        2020
#
#      Trip in a year Km travelled in a year Hours travelled in a year  UserId  \
# 0                58                    657                      16.5      37
# 1               107                   2208                      50.1    2474
# 2                34                    169                      14.2    1924
# 3                 .                      .                         .     618
# 4                18                    665                      11.9    3153
# ...             ...                    ...                       ...     ...
# 8715            216                    984                      44.1     950
# 8716              .                      .                         .    2292
# 8717              .                      .                         .    1434
# 8718             66                    649                      17.9    1336
# 8719              .                      .                         .    2968
#
#          code  ...                                        description  \
# 0     A048583  ...  This includes drivers of a passenger car (also...
# 1         NaN  ...                                                NaN
# 2     A018984  ...  Bicycle: this includes: both a non-electric an...
# 3     A018982  ...  Bus: this includes only (scheduled) buses for ...
# 4     A048584  ...  Person who rides along in a passenger car (wit...
# ...       ...  ...                                                ...
# 8715      NaN  ...                                                NaN
# 8716  A018981  ...  Includes: express train, stopping train, sprin...
# 8717  A018986  ...                                               None
# 8718  A048583  ...  This includes drivers of a passenger car (also...
# 8719  A048584  ...  Person who rides along in a passenger car (wit...
#
#      code_travel_motives                                    motive  \
# 0                2030250                                     Other
# 1                2030220        Visits including staying overnight
# 2                2030170  Travel to/from work, (non)-daily commute
# 3                2030220        Visits including staying overnight
# 4                2030220        Visits including staying overnight
# ...                  ...                                       ...
# 8715             2030200         Shopping, groceries, funshopping.
# 8716             2030190                             Services/care
# 8717             2030230                           Leisure, sports
# 8718             2030250                                     Other
# 8719             2030240                           Touring/walking
#
#                              description_travel_motives code_region  \
# 0     These include the non-commercial //bringing an...    PV23
# 1     It involves visiting and possibly staying over...    PV30
# 2     Trips to and from a permanent or a temporary w...    PV31
# 3     It involves visiting and possibly staying over...    PV20
# 4     It involves visiting and possibly staying over...    PV26
# ...                                                 ...         ...
# 8715  Shopping, grocery shopping and fun shopping (f...    PV30
# 8716  Trips to a location where a form of service or...    PV28
# 8717  This includes sport-related trips such as (whe...    PV23
# 8718  These include the non-commercial //bringing an...    PV31
# 8719  This mainly includes, in particular, recreatio...    PV29
#
#                   region                                 description_region  \
# 0        Overijssel (PV)  PV = Province Administrative classification of...
# 1     Noord-Brabant (PV)  PV = Province Administrative classification of...
# 2           Limburg (PV)  PV = Province Administrative classification of...
# 3         Groningen (PV)  PV = Province Administrative classification of...
# 4           Utrecht (PV)  PV = Province Administrative classification of...
# ...                  ...                                                ...
# 8715  Noord-Brabant (PV)  PV = Province Administrative classification of...
# 8716   Zuid-Holland (PV)  PV = Province Administrative classification of...
# 8717     Overijssel (PV)  PV = Province Administrative classification of...
# 8718        Limburg (PV)  PV = Province Administrative classification of...
# 8719        Zeeland (PV)  PV = Province Administrative classification of...
#
#                provinces    level_urbanization                  area
# 0        Overijssel (PV)  Moderately urbanised   Oost-Nederland (LD)
# 1     Noord-Brabant (PV)    Strongly urbanised   Zuid-Nederland (LD)
# 2           Limburg (PV)  Moderately urbanised   Zuid-Nederland (LD)
# 3         Groningen (PV)      Hardly urbanised  Noord-Nederland (LD)
# 4           Utrecht (PV)    Strongly urbanised   West-Nederland (LD)
# ...                  ...                   ...                   ...
# 8715  Noord-Brabant (PV)    Strongly urbanised   Zuid-Nederland (LD)
# 8716                 NaN                   NaN                   NaN
# 8717     Overijssel (PV)  Moderately urbanised   Oost-Nederland (LD)
# 8718        Limburg (PV)  Moderately urbanised   Zuid-Nederland (LD)
# 8719        Zeeland (PV)      Hardly urbanised   Zuid-Nederland (LD)
#
# [8720 rows x 21 columns]

# %%
trips_denorm=pd.merge(trips_denorm, population, how="left", left_on='Population', right_on='code', suffixes=('', '_population'))

# %%
trips_denorm.columns.tolist()
# Out:
# ['TravelMotives',
#  'Population',
#  'TravelModes',
#  'RegionCharacteristics',
#  'Periods',
#  'Trip in a year',
#  'Km travelled in a year',
#  'Hours travelled in a year',
#  'UserId',
#  'code',
#  'mode',
#  'description',
#  'code_travel_motives',
#  'motive',
#  'description_travel_motives',
#  'code_region',
#  'region',
#  'description_region',
#  'provinces',
#  'level_urbanization',
#  'area',
#  'code_population',
#  'population']

# %%
  
def toFloat(x):
  try:
      return float(x)
  except:
      return None

#trips_denorm['Km travelled in a year']=pd.to_numeric(trips_denorm['Km travelled in a year'])
trips_denorm['Trip in a year']=trips_denorm['Trip in a year'].apply(toFloat)
trips_denorm['Km travelled in a year']=trips_denorm['Km travelled in a year'].apply(toFloat)
trips_denorm['Hours travelled in a year']=trips_denorm['Hours travelled in a year'].apply(toFloat)
trips_denorm
# Out:
#       TravelMotives Population TravelModes RegionCharacteristics Periods  \
# 0           2030250    A048710     A048583              PV23        2020
# 1           2030220    A048709     T001093              PV30        2019
# 2           2030170    A048710     A018984              PV31        2022
# 3           2030220    A048709     A018982              PV20        2020
# 4           2030220    A048710     A048584              PV26        2021
# ...             ...        ...         ...                   ...     ...
# 8715        2030200    A048709     T001093              PV30        2020
# 8716        2030190    A048710     A018981              PV28        2022
# 8717        2030230    A048709     A018986              PV23        2020
# 8718        2030250    A048709     A048583              PV31        2021
# 8719        2030240    A048710     A048584              PV29        2020
#
#       Trip in a year  Km travelled in a year  Hours travelled in a year  \
# 0               58.0                   657.0                       16.5
# 1              107.0                  2208.0                       50.1
# 2               34.0                   169.0                       14.2
# 3                NaN                     NaN                        NaN
# 4               18.0                   665.0                       11.9
# ...              ...                     ...                        ...
# 8715           216.0                   984.0                       44.1
# 8716             NaN                     NaN                        NaN
# 8717             NaN                     NaN                        NaN
# 8718            66.0                   649.0                       17.9
# 8719             NaN                     NaN                        NaN
#
#       UserId     code  ...                                    motive  \
# 0         37  A048583  ...                                     Other
# 1       2474      NaN  ...        Visits including staying overnight
# 2       1924  A018984  ...  Travel to/from work, (non)-daily commute
# 3        618  A018982  ...        Visits including staying overnight
# 4       3153  A048584  ...        Visits including staying overnight
# ...      ...      ...  ...                                       ...
# 8715     950      NaN  ...         Shopping, groceries, funshopping.
# 8716    2292  A018981  ...                             Services/care
# 8717    1434  A018986  ...                           Leisure, sports
# 8718    1336  A048583  ...                                     Other
# 8719    2968  A048584  ...                           Touring/walking
#
#                              description_travel_motives  code_region  \
# 0     These include the non-commercial //bringing an...     PV23
# 1     It involves visiting and possibly staying over...     PV30
# 2     Trips to and from a permanent or a temporary w...     PV31
# 3     It involves visiting and possibly staying over...     PV20
# 4     It involves visiting and possibly staying over...     PV26
# ...                                                 ...          ...
# 8715  Shopping, grocery shopping and fun shopping (f...     PV30
# 8716  Trips to a location where a form of service or...     PV28
# 8717  This includes sport-related trips such as (whe...     PV23
# 8718  These include the non-commercial //bringing an...     PV31
# 8719  This mainly includes, in particular, recreatio...     PV29
#
#                   region                                 description_region  \
# 0        Overijssel (PV)  PV = Province Administrative classification of...
# 1     Noord-Brabant (PV)  PV = Province Administrative classification of...
# 2           Limburg (PV)  PV = Province Administrative classification of...
# 3         Groningen (PV)  PV = Province Administrative classification of...
# 4           Utrecht (PV)  PV = Province Administrative classification of...
# ...                  ...                                                ...
# 8715  Noord-Brabant (PV)  PV = Province Administrative classification of...
# 8716   Zuid-Holland (PV)  PV = Province Administrative classification of...
# 8717     Overijssel (PV)  PV = Province Administrative classification of...
# 8718        Limburg (PV)  PV = Province Administrative classification of...
# 8719        Zeeland (PV)  PV = Province Administrative classification of...
#
#                provinces    level_urbanization                  area  \
# 0        Overijssel (PV)  Moderately urbanised   Oost-Nederland (LD)
# 1     Noord-Brabant (PV)    Strongly urbanised   Zuid-Nederland (LD)
# 2           Limburg (PV)  Moderately urbanised   Zuid-Nederland (LD)
# 3         Groningen (PV)      Hardly urbanised  Noord-Nederland (LD)
# 4           Utrecht (PV)    Strongly urbanised   West-Nederland (LD)
# ...                  ...                   ...                   ...
# 8715  Noord-Brabant (PV)    Strongly urbanised   Zuid-Nederland (LD)
# 8716                 NaN                   NaN                   NaN
# 8717     Overijssel (PV)  Moderately urbanised   Oost-Nederland (LD)
# 8718        Limburg (PV)  Moderately urbanised   Zuid-Nederland (LD)
# 8719        Zeeland (PV)      Hardly urbanised   Zuid-Nederland (LD)
#
#      code_population                          population
# 0            A048710  Population 35 years old or younger
# 1            A048709   Population: 36 years old or older
# 2            A048710  Population 35 years old or younger
# 3            A048709   Population: 36 years old or older
# 4            A048710  Population 35 years old or younger
# ...              ...                                 ...
# 8715         A048709   Population: 36 years old or older
# 8716         A048710  Population 35 years old or younger
# 8717         A048709   Population: 36 years old or older
# 8718         A048709   Population: 36 years old or older
# 8719         A048710  Population 35 years old or younger
#
# [8720 rows x 23 columns]

# %%
trips_denorm.to_sql('trips_denorm', con=connIn, if_exists='replace', chunksize=1000, index=False)
# Out:
# 8720

# %% [markdown]
# # Show the total number of trips for people who went to grocery grouped by travel method and level of urbanization across all the years

# %%
trips_denorm_grossery = trips_denorm[trips_denorm['motive'] == 'Shopping, groceries, funshopping.'] 
res=trips_denorm_grossery.groupby(['Periods','mode','level_urbanization'])['Trip in a year'].sum().reset_index()


res.to_csv(os.path.join(res_dir, 'q1.csv'), index=False,encoding='utf-8') 
print(res.to_string())
# Out:
#     Periods                       mode      level_urbanization  Trip in a year
# 0      2018                       Bike     Extremely urbanised           141.0
# 1      2018                       Bike        Hardly urbanised           487.0
# 2      2018                       Bike    Moderately urbanised           359.0
# 3      2018                       Bike  Moderately urbanised\t           140.0
# 4      2018                       Bike      Strongly urbanised           272.0
# 5      2018             Bus/tram/metro     Extremely urbanised            17.0
# 6      2018             Bus/tram/metro        Hardly urbanised             0.0
# 7      2018             Bus/tram/metro    Moderately urbanised             0.0
# 8      2018             Bus/tram/metro  Moderately urbanised\t             0.0
# 9      2018             Bus/tram/metro      Strongly urbanised             0.0
# 10     2018                      Other     Extremely urbanised            12.0
# 11     2018                      Other        Hardly urbanised             0.0
# 12     2018                      Other    Moderately urbanised             0.0
# 13     2018                      Other  Moderately urbanised\t             0.0
# 14     2018                      Other      Strongly urbanised             5.0
# 15     2018     Passenger car (driver)     Extremely urbanised           122.0
# 16     2018     Passenger car (driver)        Hardly urbanised           681.0
# 17     2018     Passenger car (driver)    Moderately urbanised           603.0
# 18     2018     Passenger car (driver)  Moderately urbanised\t           166.0
# 19     2018     Passenger car (driver)      Strongly urbanised           272.0
# 20     2018  Passenger car (passenger)     Extremely urbanised            41.0
# 21     2018  Passenger car (passenger)        Hardly urbanised           198.0
# 22     2018  Passenger car (passenger)    Moderately urbanised           168.0
# 23     2018  Passenger car (passenger)  Moderately urbanised\t            46.0
# 24     2018  Passenger car (passenger)      Strongly urbanised            79.0
# 25     2018                      Train     Extremely urbanised             0.0
# 26     2018                      Train        Hardly urbanised             0.0
# 27     2018                      Train    Moderately urbanised             0.0
# 28     2018                      Train  Moderately urbanised\t             0.0
# 29     2018                      Train      Strongly urbanised             0.0
# 30     2018                    Walking     Extremely urbanised            97.0
# 31     2018                    Walking        Hardly urbanised           239.0
# 32     2018                    Walking    Moderately urbanised           203.0
# 33     2018                    Walking  Moderately urbanised\t            34.0
# 34     2018                    Walking      Strongly urbanised           163.0
# 35     2019                       Bike     Extremely urbanised           127.0
# 36     2019                       Bike        Hardly urbanised           481.0
# 37     2019                       Bike    Moderately urbanised           314.0
# 38     2019                       Bike  Moderately urbanised\t           125.0
# 39     2019                       Bike      Strongly urbanised           328.0
# 40     2019             Bus/tram/metro     Extremely urbanised            14.0
# 41     2019             Bus/tram/metro        Hardly urbanised             0.0
# 42     2019             Bus/tram/metro    Moderately urbanised             0.0
# 43     2019             Bus/tram/metro  Moderately urbanised\t             0.0
# 44     2019             Bus/tram/metro      Strongly urbanised             0.0
# 45     2019                      Other     Extremely urbanised             0.0
# 46     2019                      Other        Hardly urbanised             0.0
# 47     2019                      Other    Moderately urbanised             0.0
# 48     2019                      Other  Moderately urbanised\t             0.0
# 49     2019                      Other      Strongly urbanised             0.0
# 50     2019     Passenger car (driver)     Extremely urbanised           118.0
# 51     2019     Passenger car (driver)        Hardly urbanised           686.0
# 52     2019     Passenger car (driver)    Moderately urbanised           485.0
# 53     2019     Passenger car (driver)  Moderately urbanised\t           177.0
# 54     2019     Passenger car (driver)      Strongly urbanised           295.0
# 55     2019  Passenger car (passenger)     Extremely urbanised            39.0
# 56     2019  Passenger car (passenger)        Hardly urbanised            54.0
# 57     2019  Passenger car (passenger)    Moderately urbanised           147.0
# 58     2019  Passenger car (passenger)  Moderately urbanised\t            42.0
# 59     2019  Passenger car (passenger)      Strongly urbanised            89.0
# 60     2019                      Train     Extremely urbanised             0.0
# 61     2019                      Train        Hardly urbanised             0.0
# 62     2019                      Train    Moderately urbanised             0.0
# 63     2019                      Train  Moderately urbanised\t             0.0
# 64     2019                      Train      Strongly urbanised             0.0
# 65     2019                    Walking     Extremely urbanised           102.0
# 66     2019                    Walking        Hardly urbanised           140.0
# 67     2019                    Walking    Moderately urbanised           168.0
# 68     2019                    Walking  Moderately urbanised\t            55.0
# 69     2019                    Walking      Strongly urbanised           154.0
# 70     2020                       Bike     Extremely urbanised           123.0
# 71     2020                       Bike        Hardly urbanised           494.0
# 72     2020                       Bike    Moderately urbanised           290.0
# 73     2020                       Bike  Moderately urbanised\t           126.0
# 74     2020                       Bike      Strongly urbanised           253.0
# 75     2020             Bus/tram/metro     Extremely urbanised             8.0
# 76     2020             Bus/tram/metro        Hardly urbanised             0.0
# 77     2020             Bus/tram/metro    Moderately urbanised             0.0
# 78     2020             Bus/tram/metro  Moderately urbanised\t             0.0
# 79     2020             Bus/tram/metro      Strongly urbanised             0.0
# 80     2020                      Other     Extremely urbanised             0.0
# 81     2020                      Other        Hardly urbanised             0.0
# 82     2020                      Other    Moderately urbanised             0.0
# 83     2020                      Other  Moderately urbanised\t             0.0
# 84     2020                      Other      Strongly urbanised             0.0
# 85     2020     Passenger car (driver)     Extremely urbanised           126.0
# 86     2020     Passenger car (driver)        Hardly urbanised           690.0
# 87     2020     Passenger car (driver)    Moderately urbanised           556.0
# 88     2020     Passenger car (driver)  Moderately urbanised\t           158.0
# 89     2020     Passenger car (driver)      Strongly urbanised           403.0
# 90     2020  Passenger car (passenger)     Extremely urbanised            29.0
# 91     2020  Passenger car (passenger)        Hardly urbanised            45.0
# 92     2020  Passenger car (passenger)    Moderately urbanised           139.0
# 93     2020  Passenger car (passenger)  Moderately urbanised\t            45.0
# 94     2020  Passenger car (passenger)      Strongly urbanised            81.0
# 95     2020                      Train     Extremely urbanised             0.0
# 96     2020                      Train        Hardly urbanised             0.0
# 97     2020                      Train    Moderately urbanised             0.0
# 98     2020                      Train  Moderately urbanised\t             0.0
# 99     2020                      Train      Strongly urbanised             0.0
# 100    2020                    Walking     Extremely urbanised           110.0
# 101    2020                    Walking        Hardly urbanised           150.0
# 102    2020                    Walking    Moderately urbanised           200.0
# 103    2020                    Walking  Moderately urbanised\t            78.0
# 104    2020                    Walking      Strongly urbanised           192.0
# 105    2021                       Bike     Extremely urbanised           123.0
# 106    2021                       Bike        Hardly urbanised           438.0
# 107    2021                       Bike    Moderately urbanised           296.0
# 108    2021                       Bike  Moderately urbanised\t           110.0
# 109    2021                       Bike      Strongly urbanised           242.0
# 110    2021             Bus/tram/metro     Extremely urbanised             8.0
# 111    2021             Bus/tram/metro        Hardly urbanised             0.0
# 112    2021             Bus/tram/metro    Moderately urbanised             0.0
# 113    2021             Bus/tram/metro  Moderately urbanised\t             0.0
# 114    2021             Bus/tram/metro      Strongly urbanised             0.0
# 115    2021                      Other     Extremely urbanised            12.0
# 116    2021                      Other        Hardly urbanised             0.0
# 117    2021                      Other    Moderately urbanised             0.0
# 118    2021                      Other  Moderately urbanised\t             0.0
# 119    2021                      Other      Strongly urbanised             0.0
# 120    2021     Passenger car (driver)     Extremely urbanised           118.0
# 121    2021     Passenger car (driver)        Hardly urbanised           732.0
# 122    2021     Passenger car (driver)    Moderately urbanised           485.0
# 123    2021     Passenger car (driver)  Moderately urbanised\t           162.0
# 124    2021     Passenger car (driver)      Strongly urbanised           316.0
# 125    2021  Passenger car (passenger)     Extremely urbanised            32.0
# 126    2021  Passenger car (passenger)        Hardly urbanised            25.0
# 127    2021  Passenger car (passenger)    Moderately urbanised           137.0
# 128    2021  Passenger car (passenger)  Moderately urbanised\t            39.0
# 129    2021  Passenger car (passenger)      Strongly urbanised            70.0
# 130    2021                      Train     Extremely urbanised             0.0
# 131    2021                      Train        Hardly urbanised             0.0
# 132    2021                      Train    Moderately urbanised             0.0
# 133    2021                      Train  Moderately urbanised\t             0.0
# 134    2021                      Train      Strongly urbanised             0.0
# 135    2021                    Walking     Extremely urbanised           138.0
# 136    2021                    Walking        Hardly urbanised           168.0
# 137    2021                    Walking    Moderately urbanised           255.0
# 138    2021                    Walking  Moderately urbanised\t            94.0
# 139    2021                    Walking      Strongly urbanised           214.0
# 140    2022                       Bike     Extremely urbanised           130.0
# 141    2022                       Bike        Hardly urbanised           505.0
# 142    2022                       Bike    Moderately urbanised           344.0
# 143    2022                       Bike  Moderately urbanised\t           155.0
# 144    2022                       Bike      Strongly urbanised           269.0
# 145    2022             Bus/tram/metro     Extremely urbanised            10.0
# 146    2022             Bus/tram/metro        Hardly urbanised             0.0
# 147    2022             Bus/tram/metro    Moderately urbanised             0.0
# 148    2022             Bus/tram/metro  Moderately urbanised\t             0.0
# 149    2022             Bus/tram/metro      Strongly urbanised             0.0
# 150    2022                      Other     Extremely urbanised            10.0
# 151    2022                      Other        Hardly urbanised             0.0
# 152    2022                      Other    Moderately urbanised             0.0
# 153    2022                      Other  Moderately urbanised\t             0.0
# 154    2022                      Other      Strongly urbanised             0.0
# 155    2022     Passenger car (driver)     Extremely urbanised           116.0
# 156    2022     Passenger car (driver)        Hardly urbanised           663.0
# 157    2022     Passenger car (driver)    Moderately urbanised           494.0
# 158    2022     Passenger car (driver)  Moderately urbanised\t           167.0
# 159    2022     Passenger car (driver)      Strongly urbanised           307.0
# 160    2022  Passenger car (passenger)     Extremely urbanised            36.0
# 161    2022  Passenger car (passenger)        Hardly urbanised            47.0
# 162    2022  Passenger car (passenger)    Moderately urbanised           152.0
# 163    2022  Passenger car (passenger)  Moderately urbanised\t            46.0
# 164    2022  Passenger car (passenger)      Strongly urbanised            82.0
# 165    2022                      Train     Extremely urbanised             0.0
# 166    2022                      Train        Hardly urbanised             0.0
# 167    2022                      Train    Moderately urbanised             0.0
# 168    2022                      Train  Moderately urbanised\t             0.0
# 169    2022                      Train      Strongly urbanised             0.0
# 170    2022                    Walking     Extremely urbanised           129.0
# 171    2022                    Walking        Hardly urbanised           287.0
# 172    2022                    Walking    Moderately urbanised           231.0
# 173    2022                    Walking  Moderately urbanised\t            83.0
# 174    2022                    Walking      Strongly urbanised           193.0

# %% [markdown]
# # Show the users in west Netherlands who travelled the most by bike (in terms of kms) to go to work.

# %%
trips_wn = trips_denorm[trips_denorm['area'] == "West-Nederland (LD)"] 
trips_wn=trips_wn.groupby(['UserId','mode','motive'])['Km travelled in a year']\
    .sum().reset_index(name="Tot_Km")\
    .sort_values(['UserId','mode','Tot_Km'], ascending=False)

#print(trips_wn.to_string())

trips_wn=trips_wn.groupby('UserId').first()
trips_wn = trips_wn[(trips_wn['mode'] == "Bike") & (trips_wn['motive'] == "Travel to/from work, (non)-daily commute")]

trips_wn.to_csv(os.path.join(res_dir, 'q2.csv'), index=False,encoding='utf-8') 
print(trips_wn.to_string())
# Out:
#         mode                                    motive  Tot_Km
# UserId
# 534     Bike  Travel to/from work, (non)-daily commute   152.0
# 702     Bike  Travel to/from work, (non)-daily commute   176.0
# 739     Bike  Travel to/from work, (non)-daily commute   213.0
# 863     Bike  Travel to/from work, (non)-daily commute   332.0
# 973     Bike  Travel to/from work, (non)-daily commute   118.0
# 1161    Bike  Travel to/from work, (non)-daily commute   139.0
# 1746    Bike  Travel to/from work, (non)-daily commute   105.0
# 1914    Bike  Travel to/from work, (non)-daily commute    96.0
# 2077    Bike  Travel to/from work, (non)-daily commute   359.0
# 2195    Bike  Travel to/from work, (non)-daily commute   131.0
# 2454    Bike  Travel to/from work, (non)-daily commute   230.0
# 2593    Bike  Travel to/from work, (non)-daily commute   191.0
# 3378    Bike  Travel to/from work, (non)-daily commute   185.0

# %% [markdown]
# # Taking the top 8 users above 35 years old who travel the most km by bike, show the 3 least common motives of travel in year 2022

# %%
trips_sr = trips_denorm[trips_denorm['population'] == "Population: 36 years old or older"] 

trips_sr=trips_sr.groupby(['UserId','mode'])['Km travelled in a year']\
    .sum().reset_index(name="Tot_Km")\
    .sort_values(['UserId','mode','Tot_Km'], ascending=False)

#print(trips_sr.to_string())

trips_sr=trips_sr.groupby('UserId').first().reset_index()


trips_sr = trips_sr[(trips_sr['mode'] == "Bike")]\
    .sort_values(['Tot_Km'], ascending=False)\
    .head(8)


bike_trips=trips_denorm[ (trips_denorm['Periods'] == "2022") ]
bike_trips=bike_trips.groupby(['UserId','motive'])['Trip in a year']\
    .sum().reset_index(name="tot_trips")\
    .sort_values(['UserId','tot_trips'], ascending=True)\

bike_trips=bike_trips.groupby('UserId').head(3)

# itended among bike trips otherwise we should consider all trips (trips_denorm)
bike_trips = bike_trips[bike_trips['UserId'].isin(trips_sr['UserId'].tolist())]
bike_trips.to_csv(os.path.join(res_dir,'q3.csv'), index=False,encoding='utf-8') 

print(bike_trips.to_string())
# Out:
#       UserId                              motive  tot_trips
# 636     1373                     Touring/walking       26.0
# 635     1373                               Other      108.0
# 1212    2529  Visits including staying overnight        0.0
# 1345    2837                     Touring/walking        0.0

# %% [markdown]
# # Taking the top 10 people who took the least number of kms to atend education/courses, show for every year the average number of trips made by these users.

# %%
trips_edu=trips_denorm.groupby(['UserId','motive'])['Km travelled in a year']\
    .sum().reset_index(name="Tot_Km")\
    .sort_values(['UserId','Tot_Km'], ascending=True)


trips_edu = trips_edu[(trips_edu['motive'] == "Attending education/courses") & (trips_edu['Tot_Km'] != 0) ]\
    .sort_values(['Tot_Km'], ascending=True)\
    .head(10)


users_top10 = trips_denorm[trips_denorm['UserId'].isin(trips_edu['UserId'].tolist())]

users_top10 = users_top10.groupby(['UserId','Periods'])['Trip in a year']\
    .mean().reset_index(name="mean_trips")\
    .sort_values(['UserId','Periods'], ascending=True)

users_top10.to_csv(os.path.join(res_dir,'q4.csv'), index=False,encoding='utf-8') 

print(users_top10.to_string())
# Out:
#     UserId Periods  mean_trips
# 0      109    2018        53.0
# 1      109    2020        19.0
# 2      109    2022         7.0
# 3      110    2020         8.0
# 4      265    2020         7.0
# 5      265    2022        57.0
# 6      296    2018         NaN
# 7      296    2021         8.0
# 8      487    2018        16.0
# 9      487    2020         3.0
# 10     890    2020        28.0
# 11     890    2021         7.0
# 12     890    2022        91.0
# 13    1384    2020         NaN
# 14    1384    2022         2.0
# 15    1999    2020         8.0
# 16    2708    2020         NaN
# 17    2708    2021         2.0
# 18    3072    2021        21.0
